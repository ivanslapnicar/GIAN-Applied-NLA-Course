# %% [markdown]
# # Solutions 7 - Examples in Sparse + Low-Rank Splitting

# %% [markdown]
# ## Assignment 1
#
# We need functions from the notebook
# [L13 Sparse + Low-Rank Splitting](L13+Sparse+++Low-Rank+Splitting.ipynb).

# %%
using LinearAlgebra
# Shrinkage
function Shr(x::Array{T},τ::T) where T
    sign.(x).*max.(abs.(x).-τ,zero(T))
end

# Singular value thresholding
function D(A::Array{T},τ::T) where T
    # U,σ,V=svd(A)
    # This can be replaced by a faster approach
    U=qr(A)
    # u,σ,V
    V=svd(U.R)
    S=Shr(V.S,τ)
    # k=sum(S.>zero(T))
    k=count(!iszero,S)
    return U.Q*(V.U[:,1:k]*Diagonal(S[1:k]))*V.Vt[1:k,:]
end
# Out:
# D (generic function with 1 method)

# %%
function PCPAD(A::Array{T}) where T
    # Initialize
    δ=1.0e-7
    tol=δ*norm(A)
    m,n=size(A)
    S=zero(A)
    Y=zero(A)
    L=zero(A)
    T₁=zero(A)
    μ=(m*n)/(4*(norm(A[:],1)))
    μ₁=one(T)/μ
    λ=one(T)/sqrt(max(map(T,m),n))
    λμ₁=λ*μ₁
    ν=1e20
    maxiter=1000
    iterations=0
    # Iterate
    while (ν>tol) && iterations<maxiter
        # println(iterations," ",ν)
        iterations+=1
        L.=D(A-S+μ₁.*Y,μ₁)
        S.=Shr(A-L+μ₁.*Y,λμ₁)
        T₁.=(A-L-S)
        Y.+=(μ.*T₁)
        ν=norm(T₁)
    end
    L,S, iterations
end
# Out:
# PCPAD (generic function with 1 method)

# %%
# For compilation
A0=rand(3,3)
L,S,iter=PCPAD(A0)
# Out:
# ([0.074808 0.538248 0.228705; 0.119794 0.861924 0.366237; 0.0979962 0.705088 0.299597], [0.119405 0.292566 -0.0; 0.0 0.0 0.468141; -0.0316896 0.172448 0.0], 144)

# %%
rank(L), L+S-A0
# Out:
# (1, [-1.11022e-16 2.22045e-16 1.39324e-7; -6.99129e-8 -1.34239e-8 0.0; 1.38778e-17 -1.11022e-16 -5.13807e-8])

# %%
# Packages for video manipulation
# import Pkg; Pkg.add("VideoIO")
# import Pkg; Pkg.add("Makie")

# %%
using Images
using Makie, VideoIO
using ImageView

# %%
# varinfo(VideoIO)

# %%
v=VideoIO.open("files/visor.avi")
# Out:
# AVInput(files/visor.avi, ...), with
#   1 video stream(s)

# %%
playvideo(v)

# %%
f=VideoIO.openvideo("files/visor.avi")
# Out:
# VideoReader(...)

# %%
VideoIO.get_duration("files/visor.avi")
# Out:
# 229200000 microseconds

# %%
# Read the frames in Gray
f0 = VideoIO.openvideo("files/visor.avi",target_format=VideoIO.AV_PIX_FMT_GRAY8)
frames=Array{Array{Gray{Normed{UInt8,8}},2},1}(undef,0)
while !eof(f0)
    push!(frames,read(f0))
end
close(f0)

# %%
# Number of frames
length(frames)
# Out:
# 2292

# %%
# See particular frame
frames[1400]
# Out:
# 240×320 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(0.188)  Gray{N0f8}(0.188)  …  Gray{N0f8}(0.137)
#  Gray{N0f8}(0.188)  Gray{N0f8}(0.188)     Gray{N0f8}(0.137)
#  Gray{N0f8}(0.188)  Gray{N0f8}(0.188)     Gray{N0f8}(0.137)
#  Gray{N0f8}(0.188)  Gray{N0f8}(0.188)     Gray{N0f8}(0.137)
#  Gray{N0f8}(0.188)  Gray{N0f8}(0.188)     Gray{N0f8}(0.137)
#  Gray{N0f8}(0.188)  Gray{N0f8}(0.188)  …  Gray{N0f8}(0.137)
#  Gray{N0f8}(0.188)  Gray{N0f8}(0.188)     Gray{N0f8}(0.137)
#  Gray{N0f8}(0.188)  Gray{N0f8}(0.188)     Gray{N0f8}(0.137)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.2)       Gray{N0f8}(0.137)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.2)       Gray{N0f8}(0.137)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.2)    …  Gray{N0f8}(0.137)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.2)       Gray{N0f8}(0.137)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.2)       Gray{N0f8}(0.137)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.329)  Gray{N0f8}(0.333)     Gray{N0f8}(0.745)
#  Gray{N0f8}(0.329)  Gray{N0f8}(0.333)     Gray{N0f8}(0.761)
#  Gray{N0f8}(0.329)  Gray{N0f8}(0.333)  …  Gray{N0f8}(0.761)
#  Gray{N0f8}(0.329)  Gray{N0f8}(0.333)     Gray{N0f8}(0.745)
#  Gray{N0f8}(0.329)  Gray{N0f8}(0.333)     Gray{N0f8}(0.729)
#  Gray{N0f8}(0.337)  Gray{N0f8}(0.337)     Gray{N0f8}(0.741)
#  Gray{N0f8}(0.337)  Gray{N0f8}(0.337)     Gray{N0f8}(0.749)
#  Gray{N0f8}(0.337)  Gray{N0f8}(0.337)  …  Gray{N0f8}(0.753)
#  Gray{N0f8}(0.337)  Gray{N0f8}(0.337)     Gray{N0f8}(0.749)
#  Gray{N0f8}(0.337)  Gray{N0f8}(0.337)     Gray{N0f8}(0.729)
#  Gray{N0f8}(0.337)  Gray{N0f8}(0.337)     Gray{N0f8}(0.718)
#  Gray{N0f8}(0.337)  Gray{N0f8}(0.337)     Gray{N0f8}(0.702)

# %%
# Make shorter video clip
fshort=frames[1401:1420]
# Out:
# 20-element Array{Array{Gray{Normed{UInt8,8}},2},1}:
#  [Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); … ; Gray{N0f8}(0.337) Gray{N0f8}(0.337) … Gray{N0f8}(0.722) Gray{N0f8}(0.718); Gray{N0f8}(0.337) Gray{N0f8}(0.337) … Gray{N0f8}(0.714) Gray{N0f8}(0.702)]
#  [Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); … ; Gray{N0f8}(0.337) Gray{N0f8}(0.337) … Gray{N0f8}(0.722) Gray{N0f8}(0.718); Gray{N0f8}(0.337) Gray{N0f8}(0.337) … Gray{N0f8}(0.714) Gray{N0f8}(0.702)]
#  [Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); … ; Gray{N0f8}(0.337) Gray{N0f8}(0.337) … Gray{N0f8}(0.722) Gray{N0f8}(0.718); Gray{N0f8}(0.337) Gray{N0f8}(0.337) … Gray{N0f8}(0.714) Gray{N0f8}(0.702)]
#  [Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); … ; Gray{N0f8}(0.337) Gray{N0f8}(0.337) … Gray{N0f8}(0.722) Gray{N0f8}(0.718); Gray{N0f8}(0.337) Gray{N0f8}(0.337) … Gray{N0f8}(0.714) Gray{N0f8}(0.702)]
#  [Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); … ; Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.729) Gray{N0f8}(0.706); Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.741) Gray{N0f8}(0.714)]
#  [Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); … ; Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.729) Gray{N0f8}(0.706); Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.741) Gray{N0f8}(0.714)]
#  [Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); … ; Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.729) Gray{N0f8}(0.706); Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.741) Gray{N0f8}(0.714)]
#  [Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); … ; Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.729) Gray{N0f8}(0.706); Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.741) Gray{N0f8}(0.714)]
#  [Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); … ; Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.729) Gray{N0f8}(0.706); Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.741) Gray{N0f8}(0.714)]
#  [Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); … ; Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.729) Gray{N0f8}(0.706); Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.741) Gray{N0f8}(0.714)]
#  [Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); … ; Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.729) Gray{N0f8}(0.706); Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.741) Gray{N0f8}(0.714)]
#  [Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); … ; Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.729) Gray{N0f8}(0.706); Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.741) Gray{N0f8}(0.714)]
#  [Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); … ; Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.729) Gray{N0f8}(0.706); Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.741) Gray{N0f8}(0.714)]
#  [Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); … ; Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.729) Gray{N0f8}(0.706); Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.741) Gray{N0f8}(0.714)]
#  [Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); … ; Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.729) Gray{N0f8}(0.706); Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.741) Gray{N0f8}(0.714)]
#  [Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); Gray{N0f8}(0.188) Gray{N0f8}(0.188) … Gray{N0f8}(0.137) Gray{N0f8}(0.137); … ; Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.729) Gray{N0f8}(0.706); Gray{N0f8}(0.333) Gray{N0f8}(0.333) … Gray{N0f8}(0.741) Gray{N0f8}(0.714)]
#  [Gray{N0f8}(0.173) Gray{N0f8}(0.176) … Gray{N0f8}(0.133) Gray{N0f8}(0.133); Gray{N0f8}(0.173) Gray{N0f8}(0.176) … Gray{N0f8}(0.133) Gray{N0f8}(0.133); … ; Gray{N0f8}(0.314) Gray{N0f8}(0.322) … Gray{N0f8}(0.745) Gray{N0f8}(0.718); Gray{N0f8}(0.314) Gray{N0f8}(0.322) … Gray{N0f8}(0.745) Gray{N0f8}(0.718)]
#  [Gray{N0f8}(0.173) Gray{N0f8}(0.176) … Gray{N0f8}(0.133) Gray{N0f8}(0.133); Gray{N0f8}(0.173) Gray{N0f8}(0.176) … Gray{N0f8}(0.133) Gray{N0f8}(0.133); … ; Gray{N0f8}(0.314) Gray{N0f8}(0.322) … Gray{N0f8}(0.745) Gray{N0f8}(0.718); Gray{N0f8}(0.314) Gray{N0f8}(0.322) … Gray{N0f8}(0.745) Gray{N0f8}(0.718)]
#  [Gray{N0f8}(0.173) Gray{N0f8}(0.176) … Gray{N0f8}(0.133) Gray{N0f8}(0.133); Gray{N0f8}(0.173) Gray{N0f8}(0.176) … Gray{N0f8}(0.133) Gray{N0f8}(0.133); … ; Gray{N0f8}(0.314) Gray{N0f8}(0.322) … Gray{N0f8}(0.745) Gray{N0f8}(0.718); Gray{N0f8}(0.314) Gray{N0f8}(0.322) … Gray{N0f8}(0.745) Gray{N0f8}(0.718)]
#  [Gray{N0f8}(0.173) Gray{N0f8}(0.176) … Gray{N0f8}(0.133) Gray{N0f8}(0.133); Gray{N0f8}(0.173) Gray{N0f8}(0.176) … Gray{N0f8}(0.133) Gray{N0f8}(0.133); … ; Gray{N0f8}(0.314) Gray{N0f8}(0.322) … Gray{N0f8}(0.745) Gray{N0f8}(0.718); Gray{N0f8}(0.314) Gray{N0f8}(0.322) … Gray{N0f8}(0.745) Gray{N0f8}(0.718)]

# %%
# Turn frames into tall matrix
mi,ni=size(fshort[1])
m=mi*ni
n=length(fshort)
A=Array{Float64}(undef,m,n)
for i=1:n
    A[:,i]=vec(float(frames[i]))
end

# %%
size(A)
# Out:
# (76800, 20)

# %%
# For orientation
@time Q=qr(A);
@time D(A,0.5);
# Out:
#   0.019061 seconds (9 allocations: 11.725 MiB, 21.73% gc time)
#   0.069420 seconds (34 allocations: 46.917 MiB, 60.49% gc time)

# %%
# Compute the splitting - 4 minutes
@time L,S,iters=PCPAD(A)
# Out:
#  89.005470 seconds (48.02 k allocations: 135.118 GiB, 53.76% gc time)
# ([0.167469 0.166998 … 0.164706 0.164706; 0.168627 0.16835 … 0.164706 0.164706; … ; 0.674733 0.674623 … 0.678989 0.678989; 0.686753 0.686275 … 0.694118 0.694118], [0.00115814 0.00162898 … -0.0 -0.0; 0.0 0.000277381 … -0.0 -0.0; … ; 0.0115419 -0.0001132 … -0.000558081 0.00728506; 0.00344341 0.0 … -0.0 0.00392157], 1000)

# %%
# import Pkg; Pkg.add("JLD")

# %%
# Let us save the results
using JLD

# %%
@save "files/visor_results.jld" L S

# %%
# @load "files/visor_results.jld"

# %%
# Reconstruct the low-rank video component
rank(L), norm(A-L-S)
# Out:
# (8, 0.00024911722149806396)

# %%
svdvals(L)
# Out:
# 20-element Array{Float64,1}:
#  623.661072140644
#    4.740707158019864
#    2.206083500022584
#    1.227164051657878
#    0.8347686188450295
#    0.5555428226896659
#    0.27320066300624885
#    0.03470337529408531
#    9.464412403415408e-14
#    1.8792594271401515e-14
#    1.8588726933351198e-14
#    1.8455376486265282e-14
#    1.8371046067198346e-14
#    1.8354605774720974e-14
#    1.832455132414252e-14
#    1.8234182699060233e-14
#    1.7499651851540105e-14
#    1.6025183640731153e-14
#    1.5152296310396736e-14
#    1.2985419228667205e-14

# %%
# How to restore the video?
# First frame of the low-rank part
v1=L[:,1]
v2=reshape(v1,mi,ni)
map(Gray{Normed{UInt8,8}},v2)
# Out:
# 240×320 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(0.169)  Gray{N0f8}(0.173)  …  Gray{N0f8}(0.133)
#  Gray{N0f8}(0.169)  Gray{N0f8}(0.173)     Gray{N0f8}(0.133)
#  Gray{N0f8}(0.169)  Gray{N0f8}(0.173)     Gray{N0f8}(0.133)
#  Gray{N0f8}(0.169)  Gray{N0f8}(0.176)     Gray{N0f8}(0.133)
#  Gray{N0f8}(0.173)  Gray{N0f8}(0.184)     Gray{N0f8}(0.133)
#  Gray{N0f8}(0.173)  Gray{N0f8}(0.184)  …  Gray{N0f8}(0.133)
#  Gray{N0f8}(0.173)  Gray{N0f8}(0.184)     Gray{N0f8}(0.133)
#  Gray{N0f8}(0.176)  Gray{N0f8}(0.184)     Gray{N0f8}(0.137)
#  Gray{N0f8}(0.176)  Gray{N0f8}(0.184)     Gray{N0f8}(0.141)
#  Gray{N0f8}(0.18)   Gray{N0f8}(0.184)     Gray{N0f8}(0.141)
#  Gray{N0f8}(0.184)  Gray{N0f8}(0.188)  …  Gray{N0f8}(0.141)
#  Gray{N0f8}(0.184)  Gray{N0f8}(0.192)     Gray{N0f8}(0.141)
#  Gray{N0f8}(0.188)  Gray{N0f8}(0.192)     Gray{N0f8}(0.141)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.314)  Gray{N0f8}(0.314)     Gray{N0f8}(0.718)
#  Gray{N0f8}(0.286)  Gray{N0f8}(0.329)     Gray{N0f8}(0.729)
#  Gray{N0f8}(0.282)  Gray{N0f8}(0.333)  …  Gray{N0f8}(0.741)
#  Gray{N0f8}(0.302)  Gray{N0f8}(0.318)     Gray{N0f8}(0.698)
#  Gray{N0f8}(0.31)   Gray{N0f8}(0.318)     Gray{N0f8}(0.69)
#  Gray{N0f8}(0.306)  Gray{N0f8}(0.314)     Gray{N0f8}(0.702)
#  Gray{N0f8}(0.306)  Gray{N0f8}(0.314)     Gray{N0f8}(0.698)
#  Gray{N0f8}(0.306)  Gray{N0f8}(0.318)  …  Gray{N0f8}(0.714)
#  Gray{N0f8}(0.298)  Gray{N0f8}(0.314)     Gray{N0f8}(0.718)
#  Gray{N0f8}(0.302)  Gray{N0f8}(0.314)     Gray{N0f8}(0.678)
#  Gray{N0f8}(0.306)  Gray{N0f8}(0.314)     Gray{N0f8}(0.675)
#  Gray{N0f8}(0.294)  Gray{N0f8}(0.322)     Gray{N0f8}(0.686)

# %%
using SparseArrays
nnz(sparse(S))
# Out:
# 1052831

# %%
# First frame of the sparse part 
s1=S[:,1]
s2=reshape(s1,mi,ni)
# s2.-=minimum(s2)
map(Gray{Normed{UInt8,8}},clamp01.(s2.+0.5))
# Out:
# 240×320 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(0.502)  Gray{N0f8}(0.494)  …  Gray{N0f8}(0.498)
#  Gray{N0f8}(0.502)  Gray{N0f8}(0.498)     Gray{N0f8}(0.498)
#  Gray{N0f8}(0.502)  Gray{N0f8}(0.498)     Gray{N0f8}(0.502)
#  Gray{N0f8}(0.506)  Gray{N0f8}(0.502)     Gray{N0f8}(0.502)
#  Gray{N0f8}(0.502)  Gray{N0f8}(0.502)     Gray{N0f8}(0.502)
#  Gray{N0f8}(0.51)   Gray{N0f8}(0.502)  …  Gray{N0f8}(0.502)
#  Gray{N0f8}(0.514)  Gray{N0f8}(0.502)     Gray{N0f8}(0.502)
#  Gray{N0f8}(0.51)   Gray{N0f8}(0.506)     Gray{N0f8}(0.498)
#  Gray{N0f8}(0.514)  Gray{N0f8}(0.506)     Gray{N0f8}(0.502)
#  Gray{N0f8}(0.514)  Gray{N0f8}(0.506)     Gray{N0f8}(0.502)
#  Gray{N0f8}(0.51)   Gray{N0f8}(0.506)  …  Gray{N0f8}(0.502)
#  Gray{N0f8}(0.506)  Gray{N0f8}(0.502)     Gray{N0f8}(0.502)
#  Gray{N0f8}(0.502)  Gray{N0f8}(0.502)     Gray{N0f8}(0.502)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.49)   Gray{N0f8}(0.502)     Gray{N0f8}(0.502)
#  Gray{N0f8}(0.498)  Gray{N0f8}(0.494)     Gray{N0f8}(0.494)
#  Gray{N0f8}(0.498)  Gray{N0f8}(0.494)  …  Gray{N0f8}(0.502)
#  Gray{N0f8}(0.506)  Gray{N0f8}(0.498)     Gray{N0f8}(0.522)
#  Gray{N0f8}(0.494)  Gray{N0f8}(0.49)      Gray{N0f8}(0.498)
#  Gray{N0f8}(0.502)  Gray{N0f8}(0.494)     Gray{N0f8}(0.498)
#  Gray{N0f8}(0.502)  Gray{N0f8}(0.494)     Gray{N0f8}(0.494)
#  Gray{N0f8}(0.498)  Gray{N0f8}(0.49)   …  Gray{N0f8}(0.51)
#  Gray{N0f8}(0.51)   Gray{N0f8}(0.498)     Gray{N0f8}(0.498)
#  Gray{N0f8}(0.502)  Gray{N0f8}(0.494)     Gray{N0f8}(0.49)
#  Gray{N0f8}(0.502)  Gray{N0f8}(0.494)     Gray{N0f8}(0.51)
#  Gray{N0f8}(0.51)   Gray{N0f8}(0.486)     Gray{N0f8}(0.502)

# %%
S1=A-L
s1=S1[:,5]
s2=reshape(s1,mi,ni)
# s2.-=minimum(s2)
map(Gray{Normed{UInt8,8}},clamp01.(s2.+0.3))
# Out:
# 240×320 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(0.294)  Gray{N0f8}(0.298)  …  Gray{N0f8}(0.298)
#  Gray{N0f8}(0.29)   Gray{N0f8}(0.298)     Gray{N0f8}(0.298)
#  Gray{N0f8}(0.294)  Gray{N0f8}(0.302)     Gray{N0f8}(0.298)
#  Gray{N0f8}(0.298)  Gray{N0f8}(0.302)     Gray{N0f8}(0.302)
#  Gray{N0f8}(0.294)  Gray{N0f8}(0.302)     Gray{N0f8}(0.302)
#  Gray{N0f8}(0.294)  Gray{N0f8}(0.298)  …  Gray{N0f8}(0.302)
#  Gray{N0f8}(0.298)  Gray{N0f8}(0.302)     Gray{N0f8}(0.302)
#  Gray{N0f8}(0.294)  Gray{N0f8}(0.302)     Gray{N0f8}(0.302)
#  Gray{N0f8}(0.294)  Gray{N0f8}(0.298)     Gray{N0f8}(0.302)
#  Gray{N0f8}(0.298)  Gray{N0f8}(0.298)     Gray{N0f8}(0.302)
#  Gray{N0f8}(0.298)  Gray{N0f8}(0.294)  …  Gray{N0f8}(0.302)
#  Gray{N0f8}(0.294)  Gray{N0f8}(0.298)     Gray{N0f8}(0.302)
#  Gray{N0f8}(0.298)  Gray{N0f8}(0.298)     Gray{N0f8}(0.302)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.306)  Gray{N0f8}(0.302)     Gray{N0f8}(0.302)
#  Gray{N0f8}(0.298)  Gray{N0f8}(0.302)     Gray{N0f8}(0.29)
#  Gray{N0f8}(0.298)  Gray{N0f8}(0.302)  …  Gray{N0f8}(0.302)
#  Gray{N0f8}(0.298)  Gray{N0f8}(0.294)     Gray{N0f8}(0.298)
#  Gray{N0f8}(0.294)  Gray{N0f8}(0.298)     Gray{N0f8}(0.298)
#  Gray{N0f8}(0.298)  Gray{N0f8}(0.302)     Gray{N0f8}(0.302)
#  Gray{N0f8}(0.302)  Gray{N0f8}(0.302)     Gray{N0f8}(0.302)
#  Gray{N0f8}(0.31)   Gray{N0f8}(0.302)  …  Gray{N0f8}(0.302)
#  Gray{N0f8}(0.306)  Gray{N0f8}(0.306)     Gray{N0f8}(0.298)
#  Gray{N0f8}(0.306)  Gray{N0f8}(0.302)     Gray{N0f8}(0.306)
#  Gray{N0f8}(0.302)  Gray{N0f8}(0.298)     Gray{N0f8}(0.298)
#  Gray{N0f8}(0.302)  Gray{N0f8}(0.298)     Gray{N0f8}(0.302)

# %%
minimum(s2)
# Out:
# -0.2589754169838094

# %%
Lf=similar(fsg)
Sf=similar(fsg)
for i=1:n
    Lf[:,:,i]=reshape(L[:,i],mi,ni)
    Sf[:,:,i]=clamp01.(reshape(S[:,i],mi,ni)+0.3)
end

# %%
# Play the low-rank part
imshow(Lf)
# Out:
# Dict{String,Any} with 4 entries:
#   "gui"         => Dict{String,Any}(Pair{String,Any}("window", Gtk.GtkWindowLea…
#   "roi"         => Dict{String,Any}(Pair{String,Any}("redraw", 247: "map(clim-m…
#   "annotations" => 196: "input-72" = Dict{UInt64,Any}() Dict{UInt64,Any}
#   "clim"        => 195: "CLim" = ImageView.CLim{FixedPointNumbers.Normed{UInt8,…

# %%
# Play the sparse part
imshow(Sf)
# Out:
# Dict{String,Any} with 4 entries:
#   "gui"         => Dict{String,Any}(Pair{String,Any}("window", Gtk.GtkWindowLea…
#   "roi"         => Dict{String,Any}(Pair{String,Any}("redraw", 302: "map(clim-m…
#   "annotations" => 251: "input-91" = Dict{UInt64,Any}() Dict{UInt64,Any}
#   "clim"        => 250: "CLim" = ImageView.CLim{FixedPointNumbers.Normed{UInt8,…

# %% [markdown]
# How to improve the visibility of the sparse component?
